# %% [markdown]
# #### Importing libraries

# %%
import reader
import numpy as np
import pandas as pd
from sklearn.linear_model import Ridge, LinearRegression, LogisticRegression
from sklearn.model_selection import train_test_split
import sklearn.metrics as metrics
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# #### Loading the dataset

# %%
data=reader.get_all_data()
data.head()
# Out:
#                Property Crime  Violent Crime  Total Crime  Log Property Crime  \
# Area_name
# Abbeville, SC          307.60      52.200000   359.800000            5.729779
# Acadia, LA             569.25      45.000000   614.250000            6.327271
# Accomack, VA           536.40      70.000000   606.400000            6.280119
# Ada, ID               1079.00     159.333333  1238.333333            6.976657
# Adair, IA               44.20       4.600000    48.800000            3.793328
#
#                Log Violent Crime  Log Total Crime  Root Log Property Crime  \
# Area_name
# Abbeville, SC           3.967179         5.886334                 2.393655
# Acadia, LA              3.545000         6.398918                 2.515094
# Accomack, VA            4.255036         6.403138                 2.505909
# Ada, ID                 5.075962         7.115527                 2.641227
# Adair, IA               1.602867         3.896170                 1.947030
#
#                Root Log Violent Crime  Root Log Total Crime  \
# Area_name
# Abbeville, SC                1.991553              2.426142
# Acadia, LA                   1.873566              2.529226
# Accomack, VA                 2.062554              2.530346
# Ada, ID                      2.252961              2.667405
# Adair, IA                    1.245159              1.973473
#
#                Mean Income (Household)  Median Income (Household)  \
# Area_name
# Abbeville, SC                   41.909                     33.495
# Acadia, LA                      47.311                     33.882
# Accomack, VA                    53.054                     40.343
# Ada, ID                         71.190                     55.888
# Adair, IA                       52.090                     43.487
#
#                Per Capita Income  Income Standard Deviation (Household)  \
# Area_name
# Abbeville, SC             16.772                              34.711517
# Acadia, LA                17.704                              43.257999
# Accomack, VA              22.013                              53.847933
# Ada, ID                   27.805                              61.384253
# Adair, IA                 22.897                              42.852780
#
#                High Bracket Income (Household)  Percent High School Dropouts  \
# Area_name
# Abbeville, SC                       -60.230000                          23.1
# Acadia, LA                          284.213930                          31.7
# Accomack, VA                        358.326667                          23.7
# Ada, ID                             318.592294                           7.5
# Adair, IA                           249.226415                           7.8
#
#                Percent No Degree  Percent Any Degree
# Area_name
# Abbeville, SC          40.358297           59.641703
# Acadia, LA             32.914498           67.085502
# Accomack, VA           35.937033           64.062967
# Ada, ID                47.240193           52.759807
# Adair, IA              29.580117           70.419883

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### Histogram

# %%
data.hist(figsize=(15,15), xrot=-45, bins=18)
plt.show()

# %% [markdown]
# #### Density Plot

# %%
data.plot(kind='density', subplots=True, layout=(4,5), sharex=False, figsize=(18,18))
plt.show()

# %% [markdown]
# #### Boxplot

# %%
data.plot(kind='box', subplots=True, layout=(5,4), sharex=False, sharey=False,figsize=(18,18))
plt.show()

# %% [markdown]
# #### Finding correlation between all the features

# %%
corrmat = data.corr() 
corrmat
# Out:
#                                        Property Crime  Violent Crime  \
# Property Crime                               1.000000       0.921718
# Violent Crime                                0.921718       1.000000
# Total Crime                                  0.998446       0.941670
# Log Property Crime                           0.478668       0.396037
# Log Violent Crime                            0.510289       0.468641
# Log Total Crime                              0.486674       0.408327
# Root Log Property Crime                      0.370048       0.302862
# Root Log Violent Crime                       0.383456       0.344101
# Root Log Total Crime                         0.388989       0.323310
# Mean Income (Household)                      0.306694       0.216137
# Median Income (Household)                    0.256655       0.164843
# Per Capita Income                            0.255442       0.171605
# Income Standard Deviation (Household)        0.271039       0.217827
# High Bracket Income (Household)              0.092395       0.077526
# Percent High School Dropouts                -0.071649      -0.027148
# Percent No Degree                            0.292814       0.216133
# Percent Any Degree                          -0.292814      -0.216133
#
#                                        Total Crime  Log Property Crime  \
# Property Crime                            0.998446            0.478668
# Violent Crime                             0.941670            0.396037
# Total Crime                               1.000000            0.471443
# Log Property Crime                        0.471443            1.000000
# Log Violent Crime                         0.509285            0.891586
# Log Total Crime                           0.480299            0.996894
# Root Log Property Crime                   0.364000            0.967555
# Root Log Violent Crime                    0.381568            0.874214
# Root Log Total Crime                      0.383468            0.971042
# Mean Income (Household)                   0.296493            0.328072
# Median Income (Household)                 0.245838            0.294337
# Per Capita Income                         0.245820            0.225501
# Income Standard Deviation (Household)     0.265856            0.247222
# High Bracket Income (Household)           0.091153            0.138856
# Percent High School Dropouts             -0.066103           -0.049470
# Percent No Degree                         0.284417            0.338834
# Percent Any Degree                       -0.284417           -0.338834
#
#                                        Log Violent Crime  Log Total Crime  \
# Property Crime                                  0.510289         0.486674
# Violent Crime                                   0.468641         0.408327
# Total Crime                                     0.509285         0.480299
# Log Property Crime                              0.891586         0.996894
# Log Violent Crime                               1.000000         0.914055
# Log Total Crime                                 0.914055         1.000000
# Root Log Property Crime                         0.819328         0.960827
# Root Log Violent Crime                          0.958193         0.897859
# Root Log Total Crime                            0.855534         0.973756
# Mean Income (Household)                         0.311083         0.330390
# Median Income (Household)                       0.259116         0.295308
# Per Capita Income                               0.197540         0.224761
# Income Standard Deviation (Household)           0.267545         0.251293
# High Bracket Income (Household)                 0.142676         0.140813
# Percent High School Dropouts                    0.008094        -0.044506
# Percent No Degree                               0.349246         0.343410
# Percent Any Degree                             -0.349246        -0.343410
#
#                                        Root Log Property Crime  \
# Property Crime                                        0.370048
# Violent Crime                                         0.302862
# Total Crime                                           0.364000
# Log Property Crime                                    0.967555
# Log Violent Crime                                     0.819328
# Log Total Crime                                       0.960827
# Root Log Property Crime                               1.000000
# Root Log Violent Crime                                0.844247
# Root Log Total Crime                                  0.989716
# Mean Income (Household)                               0.253831
# Median Income (Household)                             0.231936
# Per Capita Income                                     0.159866
# Income Standard Deviation (Household)                 0.183457
# High Bracket Income (Household)                       0.111982
# Percent High School Dropouts                         -0.028632
# Percent No Degree                                     0.265278
# Percent Any Degree                                   -0.265278
#
#                                        Root Log Violent Crime  \
# Property Crime                                       0.383456
# Violent Crime                                        0.344101
# Total Crime                                          0.381568
# Log Property Crime                                   0.874214
# Log Violent Crime                                    0.958193
# Log Total Crime                                      0.897859
# Root Log Property Crime                              0.844247
# Root Log Violent Crime                               1.000000
# Root Log Total Crime                                 0.883357
# Mean Income (Household)                              0.259664
# Median Income (Household)                            0.222993
# Per Capita Income                                    0.144982
# Income Standard Deviation (Household)                0.212377
# High Bracket Income (Household)                      0.128681
# Percent High School Dropouts                         0.016243
# Percent No Degree                                    0.300426
# Percent Any Degree                                  -0.300426
#
#                                        Root Log Total Crime  \
# Property Crime                                     0.388989
# Violent Crime                                      0.323310
# Total Crime                                        0.383468
# Log Property Crime                                 0.971042
# Log Violent Crime                                  0.855534
# Log Total Crime                                    0.973756
# Root Log Property Crime                            0.989716
# Root Log Violent Crime                             0.883357
# Root Log Total Crime                               1.000000
# Mean Income (Household)                            0.269572
# Median Income (Household)                          0.245399
# Per Capita Income                                  0.169235
# Income Standard Deviation (Household)              0.197347
# High Bracket Income (Household)                    0.119536
# Percent High School Dropouts                      -0.026176
# Percent No Degree                                  0.283063
# Percent Any Degree                                -0.283063
#
#                                        Mean Income (Household)  \
# Property Crime                                        0.306694
# Violent Crime                                         0.216137
# Total Crime                                           0.296493
# Log Property Crime                                    0.328072
# Log Violent Crime                                     0.311083
# Log Total Crime                                       0.330390
# Root Log Property Crime                               0.253831
# Root Log Violent Crime                                0.259664
# Root Log Total Crime                                  0.269572
# Mean Income (Household)                               1.000000
# Median Income (Household)                             0.950084
# Per Capita Income                                     0.923479
# Income Standard Deviation (Household)                 0.775647
# High Bracket Income (Household)                       0.305478
# Percent High School Dropouts                         -0.537486
# Percent No Degree                                     0.671140
# Percent Any Degree                                   -0.671140
#
#                                        Median Income (Household)  \
# Property Crime                                          0.256655
# Violent Crime                                           0.164843
# Total Crime                                             0.245838
# Log Property Crime                                      0.294337
# Log Violent Crime                                       0.259116
# Log Total Crime                                         0.295308
# Root Log Property Crime                                 0.231936
# Root Log Violent Crime                                  0.222993
# Root Log Total Crime                                    0.245399
# Mean Income (Household)                                 0.950084
# Median Income (Household)                               1.000000
# Per Capita Income                                       0.860398
# Income Standard Deviation (Household)                   0.578494
# High Bracket Income (Household)                         0.194322
# Percent High School Dropouts                           -0.573692
# Percent No Degree                                       0.574355
# Percent Any Degree                                     -0.574355
#
#                                        Per Capita Income  \
# Property Crime                                  0.255442
# Violent Crime                                   0.171605
# Total Crime                                     0.245820
# Log Property Crime                              0.225501
# Log Violent Crime                               0.197540
# Log Total Crime                                 0.224761
# Root Log Property Crime                         0.159866
# Root Log Violent Crime                          0.144982
# Root Log Total Crime                            0.169235
# Mean Income (Household)                         0.923479
# Median Income (Household)                       0.860398
# Per Capita Income                               1.000000
# Income Standard Deviation (Household)           0.754027
# High Bracket Income (Household)                 0.314750
# Percent High School Dropouts                   -0.658942
# Percent No Degree                               0.654040
# Percent Any Degree                             -0.654040
#
#                                        Income Standard Deviation (Household)  \
# Property Crime                                                      0.271039
# Violent Crime                                                       0.217827
# Total Crime                                                         0.265856
# Log Property Crime                                                  0.247222
# Log Violent Crime                                                   0.267545
# Log Total Crime                                                     0.251293
# Root Log Property Crime                                             0.183457
# Root Log Violent Crime                                              0.212377
# Root Log Total Crime                                                0.197347
# Mean Income (Household)                                             0.775647
# Median Income (Household)                                           0.578494
# Per Capita Income                                                   0.754027
# Income Standard Deviation (Household)                               1.000000
# High Bracket Income (Household)                                     0.502838
# Percent High School Dropouts                                       -0.318071
# Percent No Degree                                                   0.592410
# Percent Any Degree                                                 -0.592410
#
#                                        High Bracket Income (Household)  \
# Property Crime                                                0.092395
# Violent Crime                                                 0.077526
# Total Crime                                                   0.091153
# Log Property Crime                                            0.138856
# Log Violent Crime                                             0.142676
# Log Total Crime                                               0.140813
# Root Log Property Crime                                       0.111982
# Root Log Violent Crime                                        0.128681
# Root Log Total Crime                                          0.119536
# Mean Income (Household)                                       0.305478
# Median Income (Household)                                     0.194322
# Per Capita Income                                             0.314750
# Income Standard Deviation (Household)                         0.502838
# High Bracket Income (Household)                               1.000000
# Percent High School Dropouts                                 -0.160067
# Percent No Degree                                             0.214534
# Percent Any Degree                                           -0.214534
#
#                                        Percent High School Dropouts  \
# Property Crime                                            -0.071649
# Violent Crime                                             -0.027148
# Total Crime                                               -0.066103
# Log Property Crime                                        -0.049470
# Log Violent Crime                                          0.008094
# Log Total Crime                                           -0.044506
# Root Log Property Crime                                   -0.028632
# Root Log Violent Crime                                     0.016243
# Root Log Total Crime                                      -0.026176
# Mean Income (Household)                                   -0.537486
# Median Income (Household)                                 -0.573692
# Per Capita Income                                         -0.658942
# Income Standard Deviation (Household)                     -0.318071
# High Bracket Income (Household)                           -0.160067
# Percent High School Dropouts                               1.000000
# Percent No Degree                                         -0.430697
# Percent Any Degree                                         0.430697
#
#                                        Percent No Degree  Percent Any Degree
# Property Crime                                  0.292814           -0.292814
# Violent Crime                                   0.216133           -0.216133
# Total Crime                                     0.284417           -0.284417
# Log Property Crime                              0.338834           -0.338834
# Log Violent Crime                               0.349246           -0.349246
# Log Total Crime                                 0.343410           -0.343410
# Root Log Property Crime                         0.265278           -0.265278
# Root Log Violent Crime                          0.300426           -0.300426
# Root Log Total Crime                            0.283063           -0.283063
# Mean Income (Household)                         0.671140           -0.671140
# Median Income (Household)                       0.574355           -0.574355
# Per Capita Income                               0.654040           -0.654040
# Income Standard Deviation (Household)           0.592410           -0.592410
# High Bracket Income (Household)                 0.214534           -0.214534
# Percent High School Dropouts                   -0.430697            0.430697
# Percent No Degree                               1.000000           -1.000000
# Percent Any Degree                             -1.000000            1.000000

# %% [markdown]
# #### Plotting the correlation between various features

# %%
sns.jointplot(x=data['Property Crime'], y=data['Violent Crime'],data=data, marginal_kws=dict(bins=15, rug=True),
...                   annot_kws=dict(stat="r"),
...                   s=60, edgecolor="w", linewidth=1)

# %%
sns.jointplot(x=data['Per Capita Income'], y=data['Income Standard Deviation (Household)'],data=data, marginal_kws=dict(bins=15, rug=True),
...                   annot_kws=dict(stat="r"),
...                   s=60, edgecolor="w", linewidth=1)

# %%
sns.jointplot(x=data['Mean Income (Household)'], y=data['Income Standard Deviation (Household)'],data=data, marginal_kws=dict(bins=15, rug=True),
...                   annot_kws=dict(stat="r"),
...                   s=60, edgecolor="w", linewidth=1)

# %%
sns.jointplot(x=data['Mean Income (Household)'], y=data['Median Income (Household)'],data=data, marginal_kws=dict(bins=15, rug=True),
...                   annot_kws=dict(stat="r"),
...                   s=60, edgecolor="w", linewidth=1)

# %%
sns.jointplot(x=data['Mean Income (Household)'], y=data['Per Capita Income'],data=data, marginal_kws=dict(bins=15, rug=True),
...                   annot_kws=dict(stat="r"),ratio=2,
...                   s=60, edgecolor="w", linewidth=1)

# %% [markdown]
# #### Plotting correlations between similar types of features

# %%
plt.scatter(data['Property Crime'],data['Violent Crime'])  
plt.xlabel('Property Crime')
plt.ylabel('Violent Crime')
plt.title('Correlation between Property Crime and Violent Crime')
plt.show()

# %%
plt.scatter(data['Percent High School Dropouts'],data['Percent No Degree'])  
plt.xlabel('Percentage of High School dropouts')
plt.ylabel('Percentage of people without degree')
plt.title('Correlation between percentage of people who dropped out of high school and people without degree')
plt.show()

# %%
plt.scatter(data['Mean Income (Household)'],data['Median Income (Household)'])  
plt.xlabel('Mean Income per household')
plt.ylabel('Median Income per household')
plt.title('Correlation between mean and median income per household')
plt.show()

# %%
plt.scatter(data['Mean Income (Household)'],data['Income Standard Deviation (Household)'])  
plt.xlabel('Mean Income per household')
plt.ylabel('Standard Deviation in Income per household')
plt.title('Correlation between mean and standarad deviation income per household')
plt.show()

# %% [markdown]
# #### Plotting correlation between Per Capita Income, Education Level and Total Crime

# %%
from mpl_toolkits import mplot3d
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 100)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = data['Percent High School Dropouts']
xdata = data['Total Crime']
ydata = data['Per Capita Income']
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='viridis', linewidth=10);
ax.set_xlabel('Total Crime')
ax.set_ylabel('Per Capita Income')
ax.set_zlabel('Percent No Degree');

# %%
ax = plt.axes(projection='3d')

# Data for a three-dimensional line
zline = np.linspace(0, 15, 100)
xline = np.sin(zline)
yline = np.cos(zline)
ax.plot3D(xline, yline, zline, 'gray')

# Data for three-dimensional scattered points
zdata = data['Percent No Degree']
xdata = data['Total Crime']
ydata = data['Per Capita Income']
ax.scatter3D(xdata, ydata, zdata, c=zdata, cmap='viridis', linewidth=10);
ax.set_xlabel('Total Crime')
ax.set_ylabel('Per Capita Income')
ax.set_zlabel('Percent No Degree');

# %% [markdown]
# #### Plotting the correlation matrix using heatmap

# %%
property = reader.get_all_property_crime()
corrprop = property.corr() 
f, ax = plt.subplots(figsize =(9, 9)) 
sns.heatmap(corrprop, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %%
violent = reader.get_all_violent_crime()
corrviol = violent.corr() 
f, ax = plt.subplots(figsize =(9, 9)) 
sns.heatmap(corrviol, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %%
columns = ["Percent High School Dropouts", "Percent Any Degree", "Median Income (Household)", "Income Standard Deviation (Household)", "Total Crime"]
to_plot = data[columns].rename(columns = {"Median Income (Household)": "Median Income", "Income Standard Deviation (Household)":"Income Std. Deviation"})
pd.plotting.scatter_matrix(to_plot, figsize=(16, 16))
plt.savefig("diagrams/income_education_crime.png")

# %%
corrmat = data.corr() 

f, ax = plt.subplots(figsize =(15, 15)) 
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)

# %% [markdown]
# #### Plotting the correlation between features using scatter plot matrix

# %%
pd.plotting.scatter_matrix(data, figsize=(22, 22))
plt.show()
